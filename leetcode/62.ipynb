# %%
def uniquePaths(m: int, n: int) -> int:
    if m == 1 or n == 1:
        return 1

    if m > n:
        m, n = n, m

    dp = [1] * n

    for i in range(1, m):
        for j in range(1, n):
            dp[j] = dp[j] + dp[j - 1]

    return dp[n - 1]
