# %%
import os

for file_num in range(52, 100 + 1):
    filename = f"leetcode{file_num}.ipynb"
    
    if not os.path.exists(filename):
        try:
            with open(filename, 'w') as f:
                f.write("")

            print(f"Created file: {filename}")
        except IOError as e:
            print(f"Error creating file {filename}: {e}")
    else:
        print(f"File already exists, skipping: {filename}")

print("File generation complete.")
# Out:
# File already exists, skipping: leetcode52.ipynb
# File already exists, skipping: leetcode53.ipynb
# File already exists, skipping: leetcode54.ipynb
# File already exists, skipping: leetcode55.ipynb
# File already exists, skipping: leetcode56.ipynb
# File already exists, skipping: leetcode57.ipynb
# File already exists, skipping: leetcode58.ipynb
# File already exists, skipping: leetcode59.ipynb
# File already exists, skipping: leetcode60.ipynb
# File already exists, skipping: leetcode61.ipynb
# File already exists, skipping: leetcode62.ipynb
# File already exists, skipping: leetcode63.ipynb
# File already exists, skipping: leetcode64.ipynb
# File already exists, skipping: leetcode65.ipynb
# File already exists, skipping: leetcode66.ipynb
# File already exists, skipping: leetcode67.ipynb
# File already exists, skipping: leetcode68.ipynb
# File already exists, skipping: leetcode69.ipynb
# File already exists, skipping: leetcode70.ipynb
# File already exists, skipping: leetcode71.ipynb
# File already exists, skipping: leetcode72.ipynb
# File already exists, skipping: leetcode73.ipynb
# File already exists, skipping: leetcode74.ipynb
# File already exists, skipping: leetcode75.ipynb
# File already exists, skipping: leetcode76.ipynb
# File already exists, skipping: leetcode77.ipynb
# File already exists, skipping: leetcode78.ipynb
# File already exists, skipping: leetcode79.ipynb
# File already exists, skipping: leetcode80.ipynb
# File already exists, skipping: leetcode81.ipynb
# File already exists, skipping: leetcode82.ipynb
# File already exists, skipping: leetcode83.ipynb
# File already exists, skipping: leetcode84.ipynb
# File already exists, skipping: leetcode85.ipynb
# File already exists, skipping: leetcode86.ipynb
# File already exists, skipping: leetcode87.ipynb
# File already exists, skipping: leetcode88.ipynb
# File already exists, skipping: leetcode89.ipynb
# File already exists, skipping: leetcode90.ipynb
# File already exists, skipping: leetcode91.ipynb
# File already exists, skipping: leetcode92.ipynb
# File already exists, skipping: leetcode93.ipynb
# File already exists, skipping: leetcode94.ipynb
# File already exists, skipping: leetcode95.ipynb
# File already exists, skipping: leetcode96.ipynb
# File already exists, skipping: leetcode97.ipynb
# File already exists, skipping: leetcode98.ipynb
# File already exists, skipping: leetcode99.ipynb
# File already exists, skipping: leetcode100.ipynb
# File generation complete.
